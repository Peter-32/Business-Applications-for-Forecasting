# %%
# Imports
# import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
# import missingno as msno
# from sklearn.preprocessing import StandardScaler
from pandasql import sqldf
from pandas.plotting import autocorrelation_plot
from statsmodels.tsa import stattools
q = lambda q: sqldf(q, globals())
# pd.set_option('display.mpl_style', 'default')
# pd.set_option('display.line_width', 5000)
# pd.set_option('display.max_columns', 60)
mpl.rcParams['figure.figsize'] = (15.0, 5.0)

# Prepare data

def prepare_data():
    page_visits = pd.read_csv('data/train_1.csv', sep=",", nrows=1)
    page_visits = _transpose_and_set_column_names(page_visits)
    return _convert_all_columns_to_integers(page_visits)

def _transpose_and_set_column_names(page_visits):
    page_visits = page_visits.T
    page_visits.columns = page_visits.iloc[0]
    return page_visits.iloc[1:]

def _convert_all_columns_to_integers(page_visits):
    for col in page_visits.columns:
        page_visits[col] = page_visits[col].astype(str).astype(int)
    return page_visits

def _UNUSED_remove_missing_values_and_print_number_removed(time_series):
    missing = pd.isnull(time_series)
    print('Number of missing values found:', missing.sum())
    time_series = time_series.loc[~missing, :]


page_visits = prepare_data()

# Stationary Process

def first_order_differencing_checks():
    first_order_diff = _get_first_order_differencing(page_visits)
    _plot_page_visits_and_first_order_differencing(page_visits, first_order_diff)
    _plot_ACF_page_visits_and_first_order_differencing(page_visits, first_order_diff)
    _print_null_hypothesis__is_stationary(page_visits, "page_visits")
    _print_null_hypothesis__is_stationary(first_order_diff, "first_order_diff")

def _get_first_order_differencing(page_visits):
    first_order_diff = page_visits.diff(1)
    return first_order_diff.iloc[1:]

def _plot_page_visits_and_first_order_differencing(page_visits, first_order_diff):
    fig, ax = plt.subplots(2, sharex=True)
    page_visits.plot(ax=ax[0], color='b')
    ax[0].set_title("Page visits")
    first_order_diff.plot(ax=ax[1], color='r')
    ax[1].set_title("First-order differences to page visits")
    plt.savefig('plots/1_page_visits.png')
    print("1_page_visits plot created\n")

def _plot_ACF_page_visits_and_first_order_differencing(page_visits, first_order_diff):
    fig, ax = plt.subplots(2, sharex=True)
    autocorrelation_plot(page_visits, ax=ax[0], color='b')
    ax[0].set_title("ACF - Page visits")
    autocorrelation_plot(first_order_diff.iloc[1:], ax=ax[1], color='r')
    ax[1].set_title("ACF - First-order differences to page visits")
    plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=2.0)
    plt.savefig('plots/2_acf.png')
    print("2_acf plot created\n")

def _print_null_hypothesis__is_stationary(time_series, time_series_name):
    print("Testing {}, the null hypothesis is that the series is stationary.  If all are accepted, let's just say the data is essentially random.".format(time_series_name))
    alpha = 0.05
    acf_time_series, confint_time_series, qstat_time_series, pvalues_time_series = stattools.acf(time_series,unbiased=True,nlags=20,qstat=True,alpha=alpha)
    for l, p_val in enumerate(pvalues_time_series):
        if p_val > alpha:
            print("Null hypothesis is accepted at lag = {} for p-val = {}".format(l, p_val))
        else:
            print("Null hypothesis is rejected at lag = {} for p-val = {}".format(l, p_val))
    print("")

def print_dicky_fuller_test_results(time_series):
    print(time_series)
    adf_result = stattools.adfuller(time_series, autolag='AIC')
    print('p-val of the ADF test in air miles flown:', adf_result[1])



first_order_differencing_checks()
print_dicky_fuller_test_results(page_visits)
# Out:
# 1_page_visits plot created
#
# 2_acf plot created
#
# Testing page_visits, the null hypothesis is that the series is stationary.  If all are accepted, let's just say the data is essentially random.
# Null hypothesis is rejected at lag = 0 for p-val = 1.8426156526561984e-07
# Null hypothesis is rejected at lag = 1 for p-val = 2.8336227787098464e-09
# Null hypothesis is rejected at lag = 2 for p-val = 1.3347437875330023e-09
# Null hypothesis is rejected at lag = 3 for p-val = 2.3827966781782752e-11
# Null hypothesis is rejected at lag = 4 for p-val = 4.9182560953515994e-11
# Null hypothesis is rejected at lag = 5 for p-val = 1.5419925837752264e-10
# Null hypothesis is rejected at lag = 6 for p-val = 1.0598418028483203e-10
# Null hypothesis is rejected at lag = 7 for p-val = 1.1204962807536418e-11
# Null hypothesis is rejected at lag = 8 for p-val = 3.390704407065585e-11
# Null hypothesis is rejected at lag = 9 for p-val = 9.563071786877232e-11
# Null hypothesis is rejected at lag = 10 for p-val = 2.465753405833515e-10
# Null hypothesis is rejected at lag = 11 for p-val = 5.930937924279927e-10
# Null hypothesis is rejected at lag = 12 for p-val = 1.436768178951052e-09
# Null hypothesis is rejected at lag = 13 for p-val = 3.4160094259733222e-09
# Null hypothesis is rejected at lag = 14 for p-val = 7.673898324310453e-09
# Null hypothesis is rejected at lag = 15 for p-val = 1.1520045774238283e-08
# Null hypothesis is rejected at lag = 16 for p-val = 2.422983662383292e-08
# Null hypothesis is rejected at lag = 17 for p-val = 4.459214766539319e-08
# Null hypothesis is rejected at lag = 18 for p-val = 9.073485016222352e-08
# Null hypothesis is rejected at lag = 19 for p-val = 1.7940162857006769e-07
#
# Testing first_order_diff, the null hypothesis is that the series is stationary.  If all are accepted, let's just say the data is essentially random.
# Null hypothesis is rejected at lag = 0 for p-val = 1.6212017335947943e-26
# Null hypothesis is rejected at lag = 1 for p-val = 2.0921836570384767e-25
# Null hypothesis is rejected at lag = 2 for p-val = 5.322769900597624e-25
# Null hypothesis is rejected at lag = 3 for p-val = 3.7571638675303846e-25
# Null hypothesis is rejected at lag = 4 for p-val = 1.3610065233401174e-24
# Null hypothesis is rejected at lag = 5 for p-val = 3.394048997442248e-24
# Null hypothesis is rejected at lag = 6 for p-val = 1.561365189693426e-23
# Null hypothesis is rejected at lag = 7 for p-val = 6.626325443163132e-24
# Null hypothesis is rejected at lag = 8 for p-val = 1.0609925133023133e-23
# Null hypothesis is rejected at lag = 9 for p-val = 3.5380603563944355e-23
# Null hypothesis is rejected at lag = 10 for p-val = 9.386010070776554e-23
# Null hypothesis is rejected at lag = 11 for p-val = 2.2680784304118867e-22
# Null hypothesis is rejected at lag = 12 for p-val = 6.515475186125762e-22
# Null hypothesis is rejected at lag = 13 for p-val = 2.1294728898203607e-21
# Null hypothesis is rejected at lag = 14 for p-val = 4.766847382106998e-21
# Null hypothesis is rejected at lag = 15 for p-val = 4.863418804211068e-21
# Null hypothesis is rejected at lag = 16 for p-val = 6.6710356218300204e-21
# Null hypothesis is rejected at lag = 17 for p-val = 1.383886579461725e-20
# Null hypothesis is rejected at lag = 18 for p-val = 3.6955862079100804e-20
# Null hypothesis is rejected at lag = 19 for p-val = 6.945590708715374e-20
#
# Page        2NE1_zh.wikipedia.org_all-access_spider
# 2015-07-01                                       18
# 2015-07-02                                       11
# 2015-07-03                                        5
# 2015-07-04                                       13
# 2015-07-05                                       14
# 2015-07-06                                        9
# 2015-07-07                                        9
# 2015-07-08                                       22
# 2015-07-09                                       26
# 2015-07-10                                       24
# 2015-07-11                                       19
# 2015-07-12                                       10
# 2015-07-13                                       14
# 2015-07-14                                       15
# 2015-07-15                                        8
# 2015-07-16                                       16
# 2015-07-17                                        8
# 2015-07-18                                        8
# 2015-07-19                                       16
# 2015-07-20                                        7
# 2015-07-21                                       11
# 2015-07-22                                       10
# 2015-07-23                                       20
# 2015-07-24                                       18
# 2015-07-25                                       15
# 2015-07-26                                       14
# 2015-07-27                                       49
# 2015-07-28                                       10
# 2015-07-29                                       16
# 2015-07-30                                       18
# ...                                             ...
# 2016-12-02                                       47
# 2016-12-03                                       15
# 2016-12-04                                       14
# 2016-12-05                                       18
# 2016-12-06                                       20
# 2016-12-07                                       14
# 2016-12-08                                       16
# 2016-12-09                                       14
# 2016-12-10                                       20
# 2016-12-11                                       60
# 2016-12-12                                       22
# 2016-12-13                                       15
# 2016-12-14                                       17
# 2016-12-15                                       19
# 2016-12-16                                       18
# 2016-12-17                                       21
# 2016-12-18                                       21
# 2016-12-19                                       47
# 2016-12-20                                       65
# 2016-12-21                                       17
# 2016-12-22                                       32
# 2016-12-23                                       63
# 2016-12-24                                       15
# 2016-12-25                                       26
# 2016-12-26                                       14
# 2016-12-27                                       20
# 2016-12-28                                       22
# 2016-12-29                                       19
# 2016-12-30                                       18
# 2016-12-31                                       20
#
# [550 rows x 1 columns]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-d2a6b65767ba> in <module>()
#     101
#     102 first_order_differencing_checks()
# --> 103 print_dicky_fuller_test_results(page_visits)
#
# <ipython-input-17-d2a6b65767ba> in print_dicky_fuller_test_results(time_series)
#      95 def print_dicky_fuller_test_results(time_series):
#      96     print(time_series)
# ---> 97     adf_result = stattools.adfuller(time_series, autolag='AIC')
#      98     print('p-val of the ADF test in air miles flown:', adf_result[1])
#      99
#
# ~/Work/commons/venv/lib/python3.6/site-packages/statsmodels/tsa/stattools.py in adfuller(x, maxlag, regression, autolag, store, regresults)
#     219
#     220     xdiff = np.diff(x)
# --> 221     xdall = lagmat(xdiff[:, None], maxlag, trim='both', original='in')
#     222     nobs = xdall.shape[0]  # pylint: disable=E1103
#     223
#
# ~/Work/commons/venv/lib/python3.6/site-packages/statsmodels/tsa/tsatools.py in lagmat(x, maxlag, trim, original, use_pandas)
#     395     if xa.ndim == 1:
#     396         xa = xa[:, None]
# --> 397     nobs, nvar = xa.shape
#     398     if original in ['ex', 'sep']:
#     399         dropidx = nvar
#
# ValueError: too many values to unpack (expected 2)

# %%
type(page_visits.index[0])
